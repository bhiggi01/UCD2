# %% [markdown]
# # **UCD Project: Can Social Media Affect Share Price**

# %% [markdown]
#                       Brian Higgins | 1st June 2022 | UCD Project

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # Introduction

# %% [markdown]
# Welcome to my UCD project on wheather or not Social Media can have an effect on the Share Price of a company.
# <br>
#
# I found my notebooks where getting large so I divided it up. Please see an outline below and an overview of the different parts.
# <br>
#
# **0. Brian Higgins UCD Project - Read me**
# - First Notebook. This notebook, outlining the order to view the project
# <br><br>
#
# **1. Github**
# - Below is the link to the notebooks on github:
#         - https://github.com/bhiggi01/UCD2
# <br>
# Datasets are loaded into the Data Folder in the Notebooks.
# <br><br>
# Saved plots have been commented out so that the code will run on your machine. These have been included in Github.
# <br><br>
# - **Datasets:** (Location found in Final Report)
#     - 14 Reddit Data Sets
#     - 1 Game Stop Share Price Data Set
#     - Project Datasets:
#         - **ucd_reddit_finance_dataset:** This is the reddit data combined 14 reddit datasets.
#         - **ucd_gme_share_price_df:** This is the projects share price data.
#         - **ucd_gme_mention_share_price_df:** This is the final cleaned and combined Reddit Game Stop Mentions and the Share Price Dataset. This is used in the modelling notebook.
#         - **Model Datasets:**
#             - **ucd_random_forest_df:** Save of Random Forest results
#             - **ucd_XG_boost_results_df:** Save of XG boost
#
#
# **2. Brian Higgins UCD Project - Processing, Cleaning and EDA**
# - Second Notebook which shows the processing of the datasets I have used, cleaning of the data and EDA.
# <br><br>
#
# **3. Brian Higgins UCD Project - Modelling: NLP/ML**
# - Third Notebook that shows Natural Language Processing as well as looking at the results of different models tried.
# <br><br>
#
# **4. Brian Higgins UCD Project- Report**
# - Written Report in PDF for the Project
# <br><br>
